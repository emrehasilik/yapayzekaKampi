# %% [markdown]
# # ✨ YAPAY ZEKA TOPLULUĞU | YAPAY ZEKA GELİŞİM KAMPI
# ## 🎖️ MIDDLE PLUS HAFTA 5

# %% [markdown]
# # LLM (Large Language Model)

# %% [markdown]
# * Large language models yani büyük dil modelleri (LLM’ler), derin öğrenme tekniklerini, özellikle de dönüştürücüler olarak bilinen sinir ağlarının bir alt kümesini kullanan gelişmiş yapay zeka modelleridir.
# * Büyük dil modeli, dil çevirisi, metin sınıflandırması, duygu analizi, metin oluşturma ve soru cevaplama gibi doğal dil işleme (NLP) görevlerini gerçekleştirmek için dönüştürücüleri kullanır. LLM’ler çeşitli kaynaklardan alınan büyük miktarda veri kümesi ile eğitilir. Muazzam boyutları onları karakterize eder. En başarılı LLM’lerden bazıları yüz milyarlarca parametreye sahiptir.
# * LLM’ler bunlar insan benzeri metinleri anlamaya ve üretmeye odaklanan belirli bir yapay zeka türüdür. GPT gibi LLM’ler, çeşitli kaynaklardan gelen büyük miktarda metin verisi kullanılarak milyarlarca parametre üzerinde eğitilmiştir. Giriş dizilerini verimli bir şekilde işlemek için dikkat mekanizmalarına sahip dönüştürücü modeller gibi derin öğrenme tekniklerini kullanır.

# %% [markdown]
# #### Büyük Dil Modellerinin Arkasındaki Amaç Nedir?

# %% [markdown]
# LLM’ler hala geliştirilme aşamasında olsa da, kullanıcılara çeşitli görevlerde yardımcı olabilir ve eğitim, sağlık, müşteri hizmetleri ve eğlence dahil olmak üzere çeşitli alanlarda ihtiyaçlarına hizmet edebilirler. LLM’lerin yaygın amaçlarından bazıları aşağıdakileri içerir:
# *    Dil çevirisi
# *    Kod ve metin oluşturma
# *    Soru cevaplama
# *    Eğitim ve öğretim
# *    Müşteri hizmetleri
# *    Hukuki araştırma ve analiz
# *    Bilimsel araştırma ve keşif

# %% [markdown]
# #### Büyük dil modellerinin uygulamaları nelerdir?

# %% [markdown]
# * Metin yazarlığı : GPT-3 ve ChatGPT dışında Claude, Llama 2, Cohere Command ve Jurassiccan orijinal kopyaları yazar. AI21 Wordspice, tarz ve ton geliştirmek için orijinal cümlelerde değişiklikler önerir.
#
# * Bilgi bankası yanıtlaması : Genellikle bilgi açısından yoğun doğal dil işleme (KI-NLP) olarak adlandırılan teknik, dijital arşivlerdeki bilgi yardımından belirli soruları yanıtlayabilen LLM'leri ifade eder. Örneğin AI21 Studio oyun alanı, genel bilgi sorularını cevaplama yeteneğine sahiptir.
#
# * Metin sınıflandırması : Kümelemeyi kullanarak LLM'ler, metni benzer anlamlarla veya duygularla sınıflandırabilir. Kullanım alanları arasında müşteri duygularını ölçme, metinler arasındaki ilişkiyi belirleme ve belge arama yer alır.
#
# * Kod oluşturma : LLM, doğal dil istemlerinden kod oluşturma konusunda etkilidir. Amazon Q Developer; Python, JavaScript, Ruby ve diğer birçok programlama dilinde kod yazabilir. Diğer kodlama uygulamaları arasında SQL sorguları oluşturma, kabuk komutları yazma ve web sitesi tasarımı yer alır.
#
# * Metin oluşturma : Kod oluşturmaya benzer şekilde metin oluşturma da eksik cümleleri tamamlayabilir, ürün belgeleri yazabilir veya Alexa Create gibi kısa bir çocuk hikâyesi yazabilir.

# %% [markdown]
# Kaynaklar:
#
# * https://medium.com/kodcular/llm-large-language-models-nedir-b%C3%BCy%C3%BCk-dil-modellerine-k%C4%B1sa-bir-giri%C5%9F-9872ce8523af
# * https://www.youtube.com/watch?v=5sLYAQS9sWQ
# * https://medium.com/@akshatsanghi22/how-to-build-your-own-large-language-model-6f7b5a2dc2b1

# %% [markdown]
# #### Google Translate Uygulaması

# %% [markdown]
# Python'da dil çevirisi yapmak için farklı kütüphaneleri kullanabilirsin. En popüler seçeneklerden biri googletrans kütüphanesidir. Bu kütüphane, Google Translate API'sini kullanarak metinleri farklı dillere çevirir.

# %% [markdown]
# Öncelikle, googletrans kütüphanesini kurman gerekiyor. Terminalde şu komutu kullanarak kurulumu yapabilirsin ==>

# %%
pip install googletrans==4.0.0-rc1

# %% [markdown]
# Öncelikle googletrans kütüphanesini import etmeliyiz.

# %%
from googletrans import Translator

# %% [markdown]
# Kullanıcıdan ceviriceğimiz metni almamız gerekiyor.

# %%
# Çevrilecek metin
text = input("Cevirmek İstediğin Metin ==> ")

# %% [markdown]
# Alınan metnin dilini ve hangi dile ceviriceğimizi tanımlamamız lazım.

# %%
# Çevirici nesnesini oluştur
translator = Translator()

# %%
# Metni Türkçeye çevir
translated = translator.translate(text, src="tr", dest="en")

# %% [markdown]
# Son olarakta cıktıları görmek icin print kullanıyoruz.

# %%
# Çeviriyi ekrana yazdır
print(f"Original Text: {text}")
print(f"Translated Text: {translated.text}")

# %% [markdown]
# Bu adımları izleyerek verdiğimiz türkçe metni basit bi şekilde cevirisini yapabiliriz.

# %% [markdown]
# #### Google Translate ve LLM :

# %% [markdown]
# * Google Translate, dil modellerini eğitirken milyonlarca çeviri örneğini (metin çiftleri) kullanır. Bu geniş veri seti, çeviri doğruluğunu artırmak için modelin dilin yapısını ve bağlamını anlamasını sağlar. Arka planda kullanılan bu tür derin öğrenme modelleri, büyük dil modellerinin bir uygulaması olarak değerlendirilebilir.
# * Bu modeller, metinleri analiz eder, öğrenir ve dilin anlamını çıkararak mantıksal sonuçlar üretir. Google Translate'in kullandığı sistem, büyük bir dil modeli olan NMT (Neural Machine Translation)'ye dayalıdır ve bu da bir LLM türüdür.
# * Google Translate'in arka planı: Google, sinir ağları ve büyük dil modelleri kullanarak diller arasında anlam bazlı çeviri yapar. Bu modeller NMT (Neural Machine Translation) üzerine inşa edilmiştir ve devasa veri setleri üzerinde eğitilmiştir.

# %% [markdown]
# #### Google Translate'in LLM Olmasının Nedenleri:

# %% [markdown]
# * Devasa Veri Kümesi: Google Translate, milyarlarca cümleyi ve metin örneğini birden fazla dilde analiz ederek eğitilir. Bu da onu büyük bir dil modeli haline getirir.
#
# * Bağlam Anlayışı: LLM'ler, sadece birebir kelime çevirisi yapmazlar; aynı zamanda metnin bağlamını ve dil bilgisi kurallarını göz önünde bulundurarak doğru ve doğal çeviriler üretirler.
#
# * Gelişmiş Sinir Ağları: Google Translate, genellikle seq2seq (sequence-to-sequence) gibi gelişmiş sinir ağı yapıları kullanarak diller arası anlam dönüşümünü gerçekleştirir. Bu da onu modern büyük dil modelleri kategorisine sokar.

# %% [markdown]
# ## Ödev
#
# Videodaki uygulamaları yapınız:
# https://www.youtube.com/watch?v=kCc8FmEb1nY&list=WL
#
# ### Not = Google Colab veya Jupyter Notebook kullanarak, kodları çıktı ile birlikte gönderin.

# %%
# Ödev kodlarını buraya yazınız.

# %% [markdown]
# Prompt Engineer Giriş : https://www.youtube.com/watch?v=R--fSB7CBIs
# - Videoyu izleyiniz ve not cıkartın.
# - Bir şablon yok. Öznel bir not. İstediğiniz Şekilde Oluşturabilirsiniz.
# - En az bir sayfa olsun.
